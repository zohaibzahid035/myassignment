# %% [markdown]
# Q1: Define Object Oriented Programming Language?
#
# Answer: Based on object oriented model, OOP language is a high level programming language. Many programming languages are object oriented bases such as C++ and Java. It creates data types of data structures and many types of functions performed on data types.
#
# Q2: List down the Benefits of OOP?
#
# Answer: Code Reusability with abstraction, inheritance, polymorphism for increased productivity. Data secured with Encapsulation data.
#
# Q3: Differentiate between function and method?
#
# Answer: Method are all same except, method is a function defined inside a class.
#
# Q4: Define the following terms: Class, Object, Behavior, Attribute
# Answer:
#
# Class: Class is the blueprint of the Object. All the properties and behaviours of objects are defined inside a class as attributes and methods.
#
# Object: Object is the real world model of class or running form of class. Object contains all the properties and behaviors defined inside class. Object is used to access the data of class.
#
# Behavior: Behaviors are the methods corresponding to the behavior of real world objects.
#
# Attribute: Attributes are the variables that are defined inside a class.

# %%
class Car():
    def __init__(self, name, model, color, company, transmission):
        self.name = name
        self.model = model
        self.color = color
        self.company = company
        self.transmission = transmission
        
    def show_properties(self):
        print("Car Properties")
        print(f"Name         : {self.name}")
        print(f"Model        : {self.model}")
        print(f"Color        : {self.color}")
        print(f"Company      : {self.company}")
        print(f"Transmission : {self.transmission} \n")
        
    
    def update_name(self, newname):
        self.name = newname
    
    def update_color(self, newcolor):
        self.color = newcolor


        

car1 = Car("corolla", 2019, "Black", "toyta", "Auto")
car2 = Car("f-series", 2009, "Brown", "ford", "Manual")
car3 = Car("golf", 2016, "Black", "volkswagen", "Auto")
car4 = Car("beetle", 2017, "Grey", "volkswagen", "Manual")
car5 = Car("civic", 2018, "White", "honda", "Auto")

# Calling methods
car1.show_properties()
car2.show_properties()
car3.show_properties()
car4.show_properties()
car5.show_properties()
        
    
# Changing name
 # before Changing
print("old name : ",car1.name)
car1.update_name("lexus")
print("updated name : ",car1.name)
# Out:
# Car Properties
# Name         : corolla
# Model        : 2019
# Color        : Black
# Company      : toyta
# Transmission : Auto
#
# Car Properties
# Name         : f-series
# Model        : 2009
# Color        : Brown
# Company      : ford
# Transmission : Manual
#
# Car Properties
# Name         : golf
# Model        : 2016
# Color        : Black
# Company      : volkswagen
# Transmission : Auto
#
# Car Properties
# Name         : beetle
# Model        : 2017
# Color        : Grey
# Company      : volkswagen
# Transmission : Manual
#
# Car Properties
# Name         : civic
# Model        : 2018
# Color        : White
# Company      : honda
# Transmission : Auto
#
# old name :  corolla
# updated name :  lexus
